# %% [markdown]
# # Quick Look For Emory

# %% [markdown]
# ## *Dependencies*

# %%
import pandas as pd

# %% [markdown]
# ## *Creating A Dataframe Of Cell Info*

# %%
# Creating dataframe
df_loc = pd.read_csv("/Users/Spencer/Desktop/Emory/sample_info.csv", 
                     delimiter='	',
                      
                     engine='python')

# Displays first five rows of dataframe
print(f'This is a printout of all the available columns within the dataframe: \n\n{df_loc.columns}')

print(' \n This is the frist five rows of the dataframe: \n')
df_loc.head()
# Out:
# This is a printout of all the available columns within the dataframe:
#
# Index(['Source Name', 'Comment[ENA_SAMPLE]', 'Material Type',
#        'Characteristics[organism]', 'Characteristics[developmental stage]',
#        'Characteristics[strain]', 'Characteristics[sex]',
#        'Characteristics[specimen with known storage state]',
#        'Characteristics[cell type]',
#        'Characteristics[single cell well quality]', 'Protocol REF',
#        'Protocol REF.1', 'Protocol REF.2', 'Extract Name', 'Material Type.1',
#        'Comment[LIBRARY_LAYOUT]', 'Comment[LIBRARY_SOURCE]',
#        'Comment[LIBRARY_STRATEGY]', 'Comment[LIBRARY_SELECTION]',
#        'Comment[ORIENTATION]', 'Comment[NOMINAL_LENGTH]',
#        'Comment[NOMINAL_SDEV]', 'Comment[spike sequence file]',
#        'Protocol REF.3', 'Performer', 'Assay Name', 'Technology Type',
#        'Comment[ENA_EXPERIMENT]', 'Scan Name', 'Comment[SUBMITTED_FILE_NAME]',
# ...

# %% [markdown]
# **The column "Comment[FASTQ_URI]" within the dataframe I have confirmed refrences the web link to obtain the fastq file for a particular cell from the website in which you pointed me to Emory.** Thus I can build a script to access any of the files in which we need to achieve data from. I downloaded one fastq file for cell one and it was around 600mb so they are decently large files.

# %%
# This is the second row of the dataframe and calling only the fastq column to view the file location in which to download
df_loc["Comment[FASTQ_URI]"][1]
# Out:
# 'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/ERR489/ERR489030/ERR489030_2.fastq.gz'
